# %% [markdown]
# ### CAPSTONE PROJECT

# %% [markdown]
# #### Problem statement:
#
# A house value is simply more than location and square footage. Like the features that make up a person, an educated party would want to know all aspects that give a house its value. For  example, you want to sell a house and you don’t know the price which you can take — it can’t be too low or too high. To find house price you usually try to find similar properties in your neighbourhood and based on gathered data you will try to assess your house price.
#
# #### Attributes of the Data:
#
# Take advantage of all of the feature variables available below, use it to analyse and predict
# house prices.
#
# 1. cid: a notation for a house
# 2. dayhours: Date house was sold
# 3. price: Price is prediction target
# 4. room_bed: Number of Bedrooms/House
# 5. room_bath: Number of bathrooms/bedrooms
# 6. living_measure: square footage of the home
# 7. lot_measure: quare footage of the lot
# 8. ceil: Total floors (levels) in house
# 9. coast: House which has a view to a waterfront
# 10. sight: Has been viewed
# 11. condition: How good the condition is (Overall)
# 12. quality: grade given to the housing unit, based on grading system
# 13. ceil_measure: square footage of house apart from basement
# 14. basement_measure: square footage of the basement
# 15. yr_built: Built Year
# 16. yr_renovated: Year when house was renovated
# 17. zipcode: zip
# 18. lat: Latitude coordinate
# 19. long: Longitude coordinate
# 20. living_measure15: Living room area in 2015(implies-- some renovations) This might
# or might not have affected the lotsize area
# 21. lot_measure15: lotSize area in 2015(implies-- some renovations)
# 22. furnished: Based on the quality of room 23: total_area: Measure of both living and lot

# %% [markdown]
# #### Objectives:
# + To understand how analytical problems are solved using tools and techniques
#
# + To understand the keypoints that needs to be made while solving a real life problem

# %% [markdown]
# #### Problem Statement:
#
# The main objective of this project is to determine the right price for the property(house) by considering various attributes given in the dataset. Main issue one faces during selling or buying the property is to fix the right price for the property. There are number of atttributes that contribute to the valuation of property. The lack of knowledge about which leads to offer too high or too low prices for the property

# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import the Dataset

# %%
df = pd.read_csv("innercity.csv")

# %%
df.head()
# Out:
#           cid         dayhours   price  room_bed  room_bath  living_measure  \
# 0  3034200666  20141107T000000  808100         4       3.25            3020
# 1  8731981640  20141204T000000  277500         4       2.50            2550
# 2  5104530220  20150420T000000  404000         3       2.50            2370
# 3  6145600285  20140529T000000  300000         2       1.00             820
# 4  8924100111  20150424T000000  699000         2       1.50            1400
#
#    lot_measure  ceil  coast  sight  ...  basement  yr_built  yr_renovated  \
# 0        13457   1.0      0      0  ...         0      1956             0
# 1         7500   1.0      0      0  ...       800      1976             0
# 2         4324   2.0      0      0  ...         0      2006             0
# 3         3844   1.0      0      0  ...         0      1916             0
# 4         4050   1.0      0      0  ...         0      1954             0
#
# ...

# %%
df.shape
# Out:
# (21613, 23)

# %% [markdown]
# + The data contains 21,613 data points with 23 attributes

# %%
df.columns
# Out:
# Index(['cid', 'dayhours', 'price', 'room_bed', 'room_bath', 'living_measure',
#        'lot_measure', 'ceil', 'coast', 'sight', 'condition', 'quality',
#        'ceil_measure', 'basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'living_measure15', 'lot_measure15', 'furnished',
#        'total_area'],
#       dtype='object')

# %%
df.dtypes
# Out:
# cid                   int64
# dayhours             object
# price                 int64
# room_bed              int64
# room_bath           float64
# living_measure        int64
# lot_measure           int64
# ceil                float64
# coast                 int64
# sight                 int64
# condition             int64
# quality               int64
# ceil_measure          int64
# basement              int64
# yr_built              int64
# yr_renovated          int64
# zipcode               int64
# lat                 float64
# long                float64
# living_measure15      int64
# lot_measure15         int64
# furnished             int64
# total_area            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cid               21613 non-null  int64
#  1   dayhours          21613 non-null  object
#  2   price             21613 non-null  int64
#  3   room_bed          21613 non-null  int64
#  4   room_bath         21613 non-null  float64
#  5   living_measure    21613 non-null  int64
#  6   lot_measure       21613 non-null  int64
#  7   ceil              21613 non-null  float64
#  8   coast             21613 non-null  int64
#  9   sight             21613 non-null  int64
#  10  condition         21613 non-null  int64
#  11  quality           21613 non-null  int64
#  12  ceil_measure      21613 non-null  int64
#  13  basement          21613 non-null  int64
#  14  yr_built          21613 non-null  int64
#  15  yr_renovated      21613 non-null  int64
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# cid                 0
# dayhours            0
# price               0
# room_bed            0
# room_bath           0
# living_measure      0
# lot_measure         0
# ceil                0
# coast               0
# sight               0
# condition           0
# quality             0
# ceil_measure        0
# basement            0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# living_measure15    0
# lot_measure15       0
# furnished           0
# total_area          0
# dtype: int64

# %%
df.nunique()
# Out:
# cid                 21436
# dayhours              372
# price                3625
# room_bed               13
# room_bath              30
# living_measure       1038
# lot_measure          9782
# ceil                    6
# coast                   2
# sight                   5
# condition               5
# quality                12
# ceil_measure          946
# basement              306
# yr_built              116
# yr_renovated           70
# zipcode                70
# lat                  5034
# long                  752
# living_measure15      777
# lot_measure15        8689
# furnished               2
# total_area          11163
# dtype: int64

# %%
for feature in df.columns:
    val = len(list(df[feature].unique()))
    uni = df[feature].unique()
    if val < 15:
        print(feature,val,uni)
        print('-'* 60)
    else:
        continue
# Out:
# room_bed 13 [ 4  3  2  5  6  1  8 33  7  0  9 10 11]
# ------------------------------------------------------------
# ceil 6 [1.  2.  3.  1.5 2.5 3.5]
# ------------------------------------------------------------
# coast 2 [0 1]
# ------------------------------------------------------------
# sight 5 [0 2 4 3 1]
# ------------------------------------------------------------
# condition 5 [5 3 4 2 1]
# ------------------------------------------------------------
# quality 12 [ 9  8  6  7 10 11  5 13 12  4  3  1]
# ------------------------------------------------------------
# furnished 2 [1 0]
# ------------------------------------------------------------

# %%
def information(df):
    df_info = pd.DataFrame()
    
    df_info['data_types'] = df.dtypes
    df_info['unique'] = df.nunique()
    df_info['null_count'] = df.isnull().sum()
    df_info['duplicate'] = df.duplicated()
    
    return df_info


information(df)
# Out:
#                  data_types  unique  null_count duplicate
# cid                   int64   21436           0       NaN
# dayhours             object     372           0       NaN
# price                 int64    3625           0       NaN
# room_bed              int64      13           0       NaN
# room_bath           float64      30           0       NaN
# living_measure        int64    1038           0       NaN
# lot_measure           int64    9782           0       NaN
# ceil                float64       6           0       NaN
# coast                 int64       2           0       NaN
# sight                 int64       5           0       NaN
# condition             int64       5           0       NaN
# quality               int64      12           0       NaN
# ceil_measure          int64     946           0       NaN
# basement              int64     306           0       NaN
# yr_built              int64     116           0       NaN
# ...

# %% [markdown]
# + From the above table it is evident that, the data set doesnot contain any duplicate values and null values in any of the column.
# + Among the 23 columns, 18 features are integer type, 4 features are float type.
# + Only one of the features i.e. dayhours is 'object' type. which can be simplified.

# %% [markdown]
# #### Data Visualization and Analysis

# %%
# Statistical Analysis
data = df.copy(deep = True)
data.describe().T
# Out:
#                     count          mean           std           min  \
# cid               21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price             21613.0  5.401822e+05  3.673622e+05  7.500000e+04
# room_bed          21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# room_bath         21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# living_measure    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# lot_measure       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# ceil              21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# coast             21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# sight             21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition         21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# quality           21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# ceil_measure      21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# basement          21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %% [markdown]
# + CID is not used for the analysis
# + For a normal distribution of data: mean = median = mode.
# + If mean > median it indicates right skewed distribution.
# + If median > mean, it indicates left skewed distribution.
# + From the above statistical result it is evident that price, room_bed, living_measures, lot_measures, sight, condition, quality, ceil_measures etc. are right skewed.
# + room_bath, yr_built and lat are left-skewed
# + ceil has the characteristics of normal distributed data.
# + Most of the columns distribution is Right-Skewed. columns like furnished and coast falls under categorical category.

# %% [markdown]
# ##### Creating a new dependant attribute(column) i.e House_age from 'dayhours' and 'yr_built'

# %%
# To create a new column by extracting only year from 'dayhours'
year = []

for i in data['dayhours']:
    y = int(str(i)[:4])
    year.append(y)
data['sold_year']= year
data.head(5)
# Out:
#           cid         dayhours   price  room_bed  room_bath  living_measure  \
# 0  3034200666  20141107T000000  808100         4       3.25            3020
# 1  8731981640  20141204T000000  277500         4       2.50            2550
# 2  5104530220  20150420T000000  404000         3       2.50            2370
# 3  6145600285  20140529T000000  300000         2       1.00             820
# 4  8924100111  20150424T000000  699000         2       1.50            1400
#
#    lot_measure  ceil  coast  sight  ...  yr_built  yr_renovated  zipcode  \
# 0        13457   1.0      0      0  ...      1956             0    98133
# 1         7500   1.0      0      0  ...      1976             0    98023
# 2         4324   2.0      0      0  ...      2006             0    98038
# 3         3844   1.0      0      0  ...      1916             0    98133
# 4         4050   1.0      0      0  ...      1954             0    98115
#
# ...

# %%
# To calculate the age of the property
data['house_age'] = data['sold_year'] - data['yr_built']
data.head(5)
# Out:
#           cid         dayhours   price  room_bed  room_bath  living_measure  \
# 0  3034200666  20141107T000000  808100         4       3.25            3020
# 1  8731981640  20141204T000000  277500         4       2.50            2550
# 2  5104530220  20150420T000000  404000         3       2.50            2370
# 3  6145600285  20140529T000000  300000         2       1.00             820
# 4  8924100111  20150424T000000  699000         2       1.50            1400
#
#    lot_measure  ceil  coast  sight  ...  yr_renovated  zipcode      lat  \
# 0        13457   1.0      0      0  ...             0    98133  47.7174
# 1         7500   1.0      0      0  ...             0    98023  47.3165
# 2         4324   2.0      0      0  ...             0    98038  47.3515
# 3         3844   1.0      0      0  ...             0    98133  47.7049
# 4         4050   1.0      0      0  ...             0    98115  47.6768
#
# ...

# %% [markdown]
# #### Univariate Analysis

# %%
fig, axes = plt.subplots(7,3, figsize = (30,40))

sns.boxplot(ax = axes[0,0], data = data, y = 'price')
sns.boxplot(ax = axes[0,1], data = data, y = 'room_bed')
sns.boxplot(ax = axes[0,2], data = data, y = 'room_bath')
sns.boxplot(ax = axes[1,0], data = data, y = 'living_measure')
sns.boxplot(ax = axes[1,1], data = data, y = 'lot_measure')
sns.boxplot(ax = axes[1,2], data = data, y = 'ceil')
sns.boxplot(ax = axes[2,0], data = data, y = 'coast')
sns.boxplot(ax = axes[2,1], data = data, y = 'sight')
sns.boxplot(ax = axes[2,2], data = data, y = 'condition')
sns.boxplot(ax = axes[3,0], data = data, y = 'quality')
sns.boxplot(ax = axes[3,1], data = data, y = 'ceil_measure')
sns.boxplot(ax = axes[3,2], data = data, y = 'basement')
sns.boxplot(ax = axes[4,0], data = data, y = 'yr_built')
sns.boxplot(ax = axes[4,1], data = data, y = 'yr_renovated')
sns.boxplot(ax = axes[4,2], data = data, y = 'zipcode')
sns.boxplot(ax = axes[5,0], data = data, y = 'lat')
sns.boxplot(ax = axes[5,1], data = data, y = 'long')
sns.boxplot(ax = axes[5,2], data = data, y = 'living_measure15')
sns.boxplot(ax = axes[6,0], data = data, y = 'lot_measure15')
sns.boxplot(ax = axes[6,1], data = data, y = 'furnished')
sns.boxplot(ax = axes[6,2], data = data, y = 'total_area')
# Out:
# <AxesSubplot:ylabel='total_area'>

# %% [markdown]
# + From the univariate analysis it is evident that almost all the attributes have outliers, which needs to be addressed before building the model.

# %% [markdown]
# #### Analysis of attributes individually

# %% [markdown]
# + Plot a countplot for the columns with lesser unique values. For 'room_bed', 'room_bath', 'ceil', 'furnished' etc.,
# + Plot distplot for the columns with greater unique values. For example 'price', 'lot_measures', 'living_measures', 'ceil_measures', 'basement_measures' etc.

# %% [markdown]
# #### 1. Dayhours

# %%
# Changing the format of dayhours i.e. to 'month year'
changed_data = data.copy()
data.dayhours = data.dayhours.str.replace('T000000', "")
data['dayhours'] = pd.to_datetime(data['dayhours'])
data.dayhours = data.dayhours.apply(lambda x: x.strftime('%m-%Y'))

# %%
data.rename(columns={'dayhours':'month_year'}, inplace=True)
data.head()
# Out:
#           cid month_year   price  room_bed  room_bath  living_measure  \
# 0  3034200666    11-2014  808100         4       3.25            3020
# 1  8731981640    12-2014  277500         4       2.50            2550
# 2  5104530220    04-2015  404000         3       2.50            2370
# 3  6145600285    05-2014  300000         2       1.00             820
# 4  8924100111    04-2015  699000         2       1.50            1400
#
#    lot_measure  ceil  coast  sight  ...  yr_renovated  zipcode      lat  \
# 0        13457   1.0      0      0  ...             0    98133  47.7174
# 1         7500   1.0      0      0  ...             0    98023  47.3165
# 2         4324   2.0      0      0  ...             0    98038  47.3515
# 3         3844   1.0      0      0  ...             0    98133  47.7049
# 4         4050   1.0      0      0  ...             0    98115  47.6768
#
#       long  living_measure15  lot_measure15  furnished  total_area  sold_year  \
# ...

# %%
data['month_year'].value_counts()
# Out:
# 04-2015    2231
# 07-2014    2211
# 06-2014    2180
# 08-2014    1940
# 10-2014    1878
# 03-2015    1875
# 09-2014    1774
# 05-2014    1768
# 12-2014    1471
# 11-2014    1411
# 02-2015    1250
# 01-2015     978
# 05-2015     646
# Name: month_year, dtype: int64

# %%
fig=plt.figure(figsize=(12,8))
sns.countplot(data.month_year)
data.month_year.value_counts()
# Out:
# 04-2015    2231
# 07-2014    2211
# 06-2014    2180
# 08-2014    1940
# 10-2014    1878
# 03-2015    1875
# 09-2014    1774
# 05-2014    1768
# 12-2014    1471
# 11-2014    1411
# 02-2015    1250
# 01-2015     978
# 05-2015     646
# Name: month_year, dtype: int64

# %% [markdown]
# + Property has been sold from May-2014 to May-2015.
#
# + Most of the houses are sold during June-July 2014 and April-2015

# %% [markdown]
# #### 2. Price

# %%
# Since number of unique values is more. let's plot distplot for the column 'price'
fig=plt.figure(figsize=(8,4))
sns.distplot(data.price)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
print('The minimum price is: ',data['price'].min())
print('The maximum price is: ',data['price'].max())
# Out:
# The minimum price is:  75000
# The maximum price is:  7700000

# %%
data['price'].value_counts()
# Out:
# 450000     172
# 350000     172
# 550000     159
# 500000     152
# 425000     150
#           ...
# 2550000      1
# 814000       1
# 327200       1
# 749400       1
# 483453       1
# Name: price, Length: 3625, dtype: int64

# %% [markdown]
# + Price of the houses in the dataset ranges from 75000 to 7700000.
# + The price of the house is rightly skewed and has outliers.
# + Majority of the properties prices are in the range of 350000 to 55000

# %% [markdown]
# #### 3 Room_bed

# %%
fig=plt.figure(figsize=(8,4))
sns.countplot(data.room_bed)
data.room_bed.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 33       1
# 11       1
# Name: room_bed, dtype: int64

# %% [markdown]
# + Properties contains a minimum of 1 bedroom and maximum value has reached upto 33.
# + Among the given dataset most of the properties has 3 bedrooms followed by 4 bedrooms i.e. about 9824 properties of 21613 has 3 bedrooms, about 6882 properties has 4 bedrooms
# + 33 seems to be an outlier value. since only one such property is available in the data set, outlier in this column can be imputed.

# %% [markdown]
# #### 4. Room_bath

# %%
fig=plt.figure(figsize=(12,6))
sns.countplot(data.room_bath)
data.room_bath.value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 0.00      10
# 1.25       9
# 6.00       6
# 5.75       4
# 0.50       4
# 6.75       2
# 6.25       2
# 6.50       2
# 8.00       2
# 7.75       1
# 7.50       1
# Name: room_bath, dtype: int64

# %% [markdown]
# + The number of bathroom varies from 0 to 8.
# + From the above graph it can be concluded that most of the properties has 2.5 bathrooms followed by 1 bathroom

# %% [markdown]
# #### 5. Living_measures

# %%
fig=plt.figure(figsize=(8,4))
sns.distplot(data.living_measure)
# Out:
# <AxesSubplot:xlabel='living_measure', ylabel='Density'>

# %%
print('The minimum living measure is: ',data['living_measure'].min(),'sq.ft')
print('The maximum living measure is: ',data['living_measure'].max(),'sq.ft')
# Out:
# The minimum living measure is:  290 sq.ft
# The maximum living measure is:  13540 sq.ft

# %% [markdown]
# + The living measures of the house varies from 290sq.ft to 13540 sq.ft.
# + From the above graph it is evident that the distribution is right skewed.
# + Majority of the houses has the living measures of 2000sq.ft.

# %% [markdown]
# #### 6. Lot_measures

# %%
fig=plt.figure(figsize=(8,4))
sns.distplot(data.lot_measure)
# Out:
# <AxesSubplot:xlabel='lot_measure', ylabel='Density'>

# %%
print('The minimum lot measure is: ',data['lot_measure'].min(),'sq.ft')
print('The maximum lot measure is: ',data['lot_measure'].max(),'sq.ft')
# Out:
# The minimum lot measure is:  520 sq.ft
# The maximum lot measure is:  1651359 sq.ft

# %% [markdown]
# + From the above plot, the inference obtained is that the distributed is highly skewed towards the right.
# + The data has too many outliers which needs to imputed.
# + Lot_measure varies from 520sq.ft to 1651359 sq.ft.

# %% [markdown]
# #### 7. Ceil

# %%
fig=plt.figure(figsize=(6,6))
sns.countplot(data.ceil)
data.ceil.value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: ceil, dtype: int64

# %% [markdown]
# + Ceil represents the number of floors in the building.
# + Majority of the houses are single storey followed by a double storey building.

# %% [markdown]
# #### 8. Coast

# %%
fig=plt.figure(figsize=(4,4))
sns.countplot(data.coast)
data.coast.value_counts()
# Out:
# 0    21450
# 1      163
# Name: coast, dtype: int64

# %% [markdown]
# + Coast indicates the present of water bodies infront of the house say lake view, sea view etc.,
# + '1' indicates the presence of the water view, '0' indicates the absence of the water view.
# + Majority of the houses in the dataset doesnot have a 'coast'. About 163 houses have a waterfront.

# %% [markdown]
# #### 9. Sight

# %%
fig=plt.figure(figsize=(4,4))
sns.countplot(data.sight)
data.sight.value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: sight, dtype: int64

# %% [markdown]
# + The values in the column 'sight' ranges from 0 to 4. Sight indicates the number of times the house has been viewed.
# + Majority of the property have not been viewed.

# %% [markdown]
# #### 10. Condition

# %%
fig=plt.figure(figsize=(4,4))
sns.countplot(data.condition)
data.condition.value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %% [markdown]
# + Condition indicates the overall condition of the house (i.e. is it in a good condition or poor condition).
# + It is measured on a scale of 1 to 5.
# + Majority of the properties falls under the category '3', indicating average condition of the building.

# %% [markdown]
# #### 11 Quality

# %%
fig=plt.figure(figsize=(10,5))
sns.countplot(data.quality)
data.quality.value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: quality, dtype: int64

# %% [markdown]
# + Quality is the grade given to the housing unit based on the grading system.
# + Most properties have the quality rating between 6 to 10

# %% [markdown]
# #### 12. Ceil_measure

# %%
plt.figure(figsize=(12,6))
sns.distplot(data.ceil_measure)
# Out:
# <AxesSubplot:xlabel='ceil_measure', ylabel='Density'>

# %%
print('The minimum ceil measure is: ',data['ceil_measure'].min(),'sq.ft')
print('The maximum ceil measure is: ',data['ceil_measure'].max(),'sq.ft')
# Out:
# The minimum ceil measure is:  290 sq.ft
# The maximum ceil measure is:  9410 sq.ft

# %% [markdown]
# + Ceil measure indicates the dimension of the house apart from basement.
# + The value ranges from 290sq.ft to 9410 sq.ft

# %% [markdown]
# #### 13. Basement

# %%
plt.figure(figsize=(12,6))
sns.distplot(data.basement)
data.basement.value_counts()
# Out:
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 2120        1
# 784         1
# 946         1
# 1525        1
# 2350        1
# Name: basement, Length: 306, dtype: int64

# %% [markdown]
# + More than 50% of the properties doenot have basement.
# + Among the rest 50% that has basement has many outliers.

# %% [markdown]
# #### 14. Year built

# %%
plt.figure(figsize=(12,6))
sns.distplot(data.yr_built)
data.yr_built.value_counts()
# Out:
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %% [markdown]
# + Construction of houses began from 1934 and the variation can be found till the year 2014. The maximum number of property was built in the year 2014 followed by 2006 to 2003.

# %% [markdown]
# #### 15. Year renovated

# %%
data[data.yr_renovated>0].shape
# Out:
# (914, 25)

# %%
renovated_data = data[data.yr_renovated>0]
plt.figure(figsize=(12,6))
sns.distplot(renovated_data.yr_renovated)
# Out:
# <AxesSubplot:xlabel='yr_renovated', ylabel='Density'>

# %% [markdown]
# + About 914 houses were renovated out of 21613 houses

# %% [markdown]
# #### 16.Furnished

# %%
fig=plt.figure(figsize=(4,4))
sns.countplot(data.furnished)
data.furnished.value_counts()
# Out:
# 0    17362
# 1     4251
# Name: furnished, dtype: int64

# %% [markdown]
# + About 80% (17362) of the houses are not furnished
# + 20% of the total houses are furnished

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.close();
sns.pairplot(data,vars = ['ceil_measure','basement','living_measure','lot_measure','total_area','price'],size=5);
plt.show()

# %%
# Insights for bivariate analysis

# %%
corr_data = data.corr(method ='pearson')
corr_data
# Out:
#                        cid     price  room_bed  room_bath  living_measure  \
# cid               1.000000 -0.016797  0.001286   0.005160       -0.012258
# price            -0.016797  1.000000  0.308338   0.525134        0.702044
# room_bed          0.001286  0.308338  1.000000   0.515884        0.576671
# room_bath         0.005160  0.525134  0.515884   1.000000        0.754665
# living_measure   -0.012258  0.702044  0.576671   0.754665        1.000000
# lot_measure      -0.132109  0.089655  0.031703   0.087740        0.172826
# ceil              0.018525  0.256786  0.175429   0.500653        0.353949
# coast            -0.002721  0.266331 -0.006582   0.063744        0.103818
# sight             0.011592  0.397346  0.079532   0.187737        0.284611
# condition        -0.023783  0.036392  0.028472  -0.124982       -0.058753
# quality           0.008130  0.667463  0.356967   0.664983        0.762704
# ceil_measure     -0.010842  0.605566  0.477600   0.685342        0.876597
# ...

# %%
plt.subplots(figsize =(25, 25)) 
sns.heatmap(corr_data,annot=True);

# %% [markdown]
# ## Data Pre-processing

# %%
# Inter quartile range = IQR
# Lower whisker limit below which the values are outliers = (q1 - 1.5*iqr)
# Higher whisker limit beyond which the values are outliers = (q3 + 1.5*iqr)

def outlier_imputing(datacolumn):
    sorted(datacolumn)
    q1, q3 = np.percentile(datacolumn, [25,75]) 
    IQR = q3 - q1    
    
    low_range = q1-(1.5*IQR)    
    high_range = q3+(1.5*IQR)
    return low_range, high_range


#lower_value, upper_value = outlier_imputing(data.column)
#x = data.drop(data[(data.column > upper_value) | (data.column < lower_value) ].index, inplace=True)

# %% [markdown]
# #### Treating outliers of ceil measures

# %%
lower_value, upper_value = outlier_imputing(data.ceil_measure)
data[(data.ceil_measure < lower_value) | (data.ceil_measure > upper_value)]
# Out:
#               cid month_year    price  room_bed  room_bath  living_measure  \
# 33     7237500390    11-2014  1570000         5       4.50            6070
# 105     326069026    01-2015   900000         4       3.00            3810
# 121    3425069117    08-2014  1280000         6       5.25            6160
# 197    2125059013    04-2015  1670000         5       3.50            4320
# 232    6154500030    06-2014  1080000         4       3.50            3990
# ...           ...        ...      ...       ...        ...             ...
# 21484  1560920450    09-2014   550000         4       3.00            4180
# 21495   853600150    05-2014  1680000         4       4.25            5584
# 21554  9206700060    11-2014   710000         4       2.50            4070
# 21566  1651500040    08-2014  1980000         4       4.00            4360
# 21572  8043700105    04-2015  2300000         4       4.00            4360
#
# ...

# %%
data.drop(data[(data.ceil_measure > upper_value) | (data.ceil_measure < lower_value) ].index, inplace=True)
fig=plt.figure(figsize=(8,4))
sns.distplot(data.ceil_measure)
# Out:
# <AxesSubplot:xlabel='ceil_measure', ylabel='Density'>

# %% [markdown]
# #### Treating outliers for basement

# %%
lower_value, upper_value = outlier_imputing(data.basement)
data[(data.basement < lower_value) | (data.basement > upper_value)]
# Out:
#               cid month_year    price  room_bed  room_bath  living_measure  \
# 14     5072100095    11-2014   554000         5       2.50            3440
# 28     7855000460    10-2014  1450000         3       2.75            3940
# 46      240000058    04-2015   469000         4       2.75            3550
# 50     5154700060    10-2014  1660000         4       2.75            3520
# 51     5561400220    08-2014   592500         4       2.50            3370
# ...           ...        ...      ...       ...        ...             ...
# 21401  9315600050    03-2015  1680000         5       3.25            4560
# 21486  3582900280    06-2014  1120000         5       2.75            4400
# 21494  3395000070    09-2014  1540000         4       2.75            4910
# 21501  2021201000    05-2014   980000         4       3.00            3680
# 21549  1959703070    10-2014   979700         5       3.00            3730
#
# ...

# %%
data.drop(data[(data.basement > upper_value) | (data.basement < lower_value) ].index, inplace=True)

# %% [markdown]
# #### Treating outliers for living measure

# %%
lower_value, upper_value = outlier_imputing(data.living_measure)
data[(data.living_measure < lower_value) | (data.living_measure > upper_value)]
# Out:
#               cid month_year    price  room_bed  room_bath  living_measure  \
# 372    7636800041    06-2014   995000         3       4.50            4380
# 462    3271800910    07-2014  1360000         4       3.50            4270
# 551    1024049024    12-2014  1740000         5       3.50            4870
# 567    9185700485    04-2015  2540000         4       3.50            4350
# 780     624111000    08-2014   950000         3       3.00            4040
# ...           ...        ...      ...       ...        ...             ...
# 21062  3303980140    04-2015  1150000         4       3.00            4160
# 21125  5700003630    06-2014  1930000         5       4.25            4830
# 21405  1624059224    06-2014  1160000         4       3.50            4680
# 21552  3575303430    10-2014   780000         6       4.25            4310
# 21557  3758900075    05-2014  1530000         5       4.50            4270
#
# ...

# %%
data.drop(data[(data.living_measure > upper_value) | (data.living_measure < lower_value) ].index, inplace=True)
fig=plt.figure(figsize=(8,4))
sns.distplot(data.living_measure)
# Out:
# <AxesSubplot:xlabel='living_measure', ylabel='Density'>

# %% [markdown]
# #### Treating outliers for lot measure

# %%
lower_value, upper_value = outlier_imputing(data.lot_measure)
data[(data.lot_measure < lower_value) | (data.lot_measure > upper_value)]
# Out:
#               cid month_year   price  room_bed  room_bath  living_measure  \
# 7       114101161    08-2014  480000         3       1.50            2100
# 12     2215800050    04-2015  785000         4       2.50            3440
# 36      224069195    06-2014  759950         3       2.50            3100
# 40     2524069072    06-2014  243800         3       1.00            1140
# 45       87000213    06-2014  129000         2       1.00            1150
# ...           ...        ...     ...       ...        ...             ...
# 21547  4045500715    12-2014  598800         1       1.00            1090
# 21564  4045700455    03-2015  363000         3       0.75            2510
# 21565  5561301220    06-2014  589900         4       4.50            3870
# 21584  1626079066    08-2014  290000         2       1.00            1120
# 21590  1526079026    08-2014  487500         5       3.50            3530
#
#        lot_measure  ceil  coast  sight  ...  yr_renovated  zipcode      lat  \
# ...

# %%
data.drop(data[(data.lot_measure > upper_value) | (data.lot_measure < lower_value) ].index, inplace=True)
fig=plt.figure(figsize=(8,4))
sns.distplot(data.lot_measure)
# Out:
# <AxesSubplot:xlabel='lot_measure', ylabel='Density'>

# %% [markdown]
# #### Treating outliers for room bed

# %%
# The outliers for room_bed = 33 from univariate analysis
data[data['room_bed'] == 33]
# Out:
#             cid month_year   price  room_bed  room_bath  living_measure  \
# 750  2402100895    06-2014  640000        33       1.75            1620
#
#      lot_measure  ceil  coast  sight  ...  yr_renovated  zipcode      lat  \
# 750         6000   1.0      0      0  ...             0    98103  47.6878
#
#         long  living_measure15  lot_measure15  furnished  total_area  \
# 750 -122.331              1330           4700          0        7620
#
#      sold_year  house_age
# 750       2014         67
#
# [1 rows x 25 columns]

# %%
data.drop(data[(data.room_bed == 33)].index, inplace=True)

# %%
# To find the shape of the dataset after the treatment of outliers
data.shape
# Out:
# (18287, 25)

# %% [markdown]
# #### To drop unwanted columns

# %%
edited_data = data.copy(deep=True)

# %%
edited_data.head()
# Out:
#           cid month_year   price  room_bed  room_bath  living_measure  \
# 0  3034200666    11-2014  808100         4       3.25            3020
# 1  8731981640    12-2014  277500         4       2.50            2550
# 2  5104530220    04-2015  404000         3       2.50            2370
# 3  6145600285    05-2014  300000         2       1.00             820
# 4  8924100111    04-2015  699000         2       1.50            1400
#
#    lot_measure  ceil  coast  sight  ...  yr_renovated  zipcode      lat  \
# 0        13457   1.0      0      0  ...             0    98133  47.7174
# 1         7500   1.0      0      0  ...             0    98023  47.3165
# 2         4324   2.0      0      0  ...             0    98038  47.3515
# 3         3844   1.0      0      0  ...             0    98133  47.7049
# 4         4050   1.0      0      0  ...             0    98115  47.6768
#
#       long  living_measure15  lot_measure15  furnished  total_area  sold_year  \
# ...

# %%
edited_data = edited_data.drop(['cid','month_year','yr_renovated','zipcode','lat','long'],axis=1)

# %%
edited_data.shape
# Out:
# (18287, 19)

# %% [markdown]
# To create dummies for categorical variables: 'room_bed', 'room_bath', 'ceil', 'coast', 'sight', 'condition', 'quality', 'furnished'

# %%
edited_data = pd.get_dummies(edited_data, columns=['room_bed', 'room_bath', 'ceil', 'coast', 'sight', 'condition', 'quality', 'furnished'],drop_first=True)

# %%
edited_data.columns
# Out:
# Index(['price', 'living_measure', 'lot_measure', 'ceil_measure', 'basement',
#        'yr_built', 'living_measure15', 'lot_measure15', 'total_area',
#        'sold_year', 'house_age', 'room_bed_1', 'room_bed_2', 'room_bed_3',
#        'room_bed_4', 'room_bed_5', 'room_bed_6', 'room_bed_7', 'room_bed_8',
#        'room_bed_9', 'room_bed_10', 'room_bed_11', 'room_bath_0.5',
#        'room_bath_0.75', 'room_bath_1.0', 'room_bath_1.25', 'room_bath_1.5',
#        'room_bath_1.75', 'room_bath_2.0', 'room_bath_2.25', 'room_bath_2.5',
#        'room_bath_2.75', 'room_bath_3.0', 'room_bath_3.25', 'room_bath_3.5',
#        'room_bath_3.75', 'room_bath_4.0', 'room_bath_4.25', 'room_bath_4.5',
#        'room_bath_4.75', 'room_bath_5.0', 'room_bath_5.25', 'room_bath_5.75',
#        'ceil_1.5', 'ceil_2.0', 'ceil_2.5', 'ceil_3.0', 'ceil_3.5', 'coast_1',
#        'sight_1', 'sight_2', 'sight_3', 'sight_4', 'condition_2',
# ...

# %% [markdown]
# ### Model Building

# %%
# Machine learning Libraries 
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from scipy.stats import zscore

# %%
# Importing Libraries for modelling
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Separate the target variable and dependent variables and split the data into train and test data
X = edited_data.drop(columns = 'price', axis =1)
Y = edited_data['price']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3, random_state = 42)

# %%
ResultsDF = pd.DataFrame({'METHOD':[], 'Data type':[], 'Training_accuracy':[],'Testing_accuracy':[], 'r2_score':[], 'Mean_squared_error':[],
                          'Mean_absolute_error':[]})
ResultsDF
# Out:
# Empty DataFrame
# Columns: [METHOD, Data type, Training_accuracy, Testing_accuracy, r2_score, Mean_squared_error, Mean_absolute_error]
# Index: []

# %%
# Function to calculate model performance of given model and data set

def model_performance(model,method, data_type, X_train, X_test, Y_train, Y_test):
    """Input: Takes Machine leaning model, method used, training and test data set as input
        * model : Machine learning used
        * method : Method used of machine learning model (eg: SVM, NB, KNN, DT, RF)
        * X_train, X_test : Training and testing independent features
        * Y_train, Y_test : Training and testing target variable
       Output: Prints out model performance for given model 
       and adds difference performance measures to the result dataframe"""
    
    global ResultsDF
    model.fit(X_train, Y_train)
    
    print('Method: ', str(method))
    print('--'*10)
    train_acc = model.score(X_train, Y_train)
    print("Accuracy score for training data: ",train_acc)
    test_acc = model.score(X_test, Y_test)
    print("Accuracy score for test data: ",test_acc)
    print()
    y_pred = model.predict(X_test)

    model_r2_score = "%.3f" %float(r2_score(Y_test, y_pred))    
    model_mse = "%.3f" %float(mean_squared_error(Y_test, y_pred))
    model_mae = round(mean_absolute_error(Y_test, y_pred),3)

    TempResultsDF = pd.DataFrame({'METHOD':[str(method)],'Data type':[str(data_type)], 'Training_accuracy':train_acc,'Testing_accuracy':test_acc, 'r2_score':model_r2_score,
                                  'Mean_squared_error':model_mse, 'Mean_absolute_error':model_mae})
    ResultsDF = pd.concat([ResultsDF, TempResultsDF], ignore_index=True)
    
    return ResultsDF

# %% [markdown]
# ### 1. Linear Regression Model

# %%
LR_model = LinearRegression()
model_performance(LR_model, 'Linear Regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Linear Regression
# --------------------
# Accuracy score for training data:  0.6214685897065774
# Accuracy score for test data:  0.33986070414112834
#               METHOD    Data type  Training_accuracy  Testing_accuracy  \
# 0  Linear Regression  No outliers           0.621469          0.339861
#
#   r2_score Mean_squared_error  Mean_absolute_error
# 0    0.340    46262383262.147           116607.458

# %% [markdown]
# ### 2. Lasso Regression

# %%
lasso_reg_model = Lasso()
model_performance(lasso_reg_model, 'Lasso Regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Lasso Regression
# --------------------
# Accuracy score for training data:  0.6214268160793692
# Accuracy score for test data:  0.615349629843148
#               METHOD    Data type  Training_accuracy  Testing_accuracy  \
# 0  Linear Regression  No outliers           0.621469          0.339861
# 1   Lasso Regression  No outliers           0.621427          0.615350
#
#   r2_score Mean_squared_error  Mean_absolute_error
# 0    0.340    46262383262.147           116607.458
# 1    0.615    26956193878.704           114152.710

# %% [markdown]
# ### 3. Ridge Regression

# %%
RR_model = Ridge()
model_performance(RR_model, 'Ridge Regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Ridge Regression
# --------------------
# Accuracy score for training data:  0.6211356454458825
# Accuracy score for test data:  0.6165274915191328
#               METHOD    Data type  Training_accuracy  Testing_accuracy  \
# 0  Linear Regression  No outliers           0.621469          0.339861
# 1   Lasso Regression  No outliers           0.621427          0.615350
# 2   Ridge Regression  No outliers           0.621136          0.616527
#
#   r2_score Mean_squared_error  Mean_absolute_error
# 0    0.340    46262383262.147           116607.458
# 1    0.615    26956193878.704           114152.710
# 2    0.617    26873649651.105           114151.177

# %% [markdown]
# ### 4.KNN Regressor

# %%
KNN_model = KNeighborsRegressor()
model_performance(KNN_model, 'KNeighbors Regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  KNeighbors Regression
# --------------------
# Accuracy score for training data:  0.6161369122996266
# Accuracy score for test data:  0.4086984822636276
#                   METHOD    Data type  Training_accuracy  Testing_accuracy  \
# 0      Linear Regression  No outliers           0.621469          0.339861
# 1       Lasso Regression  No outliers           0.621427          0.615350
# 2       Ridge Regression  No outliers           0.621136          0.616527
# 3  KNeighbors Regression  No outliers           0.616137          0.408698
#
#   r2_score Mean_squared_error  Mean_absolute_error
# 0    0.340    46262383262.147           116607.458
# 1    0.615    26956193878.704           114152.710
# 2    0.617    26873649651.105           114151.177
# 3    0.409    41438250394.440           138810.442

# %% [markdown]
# ### 5. SVM

# %%
svm_model = SVR()
model_performance(svm_model, 'SVM', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  SVM
# --------------------
# Accuracy score for training data:  -0.04786634673297452
# Accuracy score for test data:  -0.05184232385217791
#                   METHOD    Data type  Training_accuracy  Testing_accuracy  \
# 0      Linear Regression  No outliers           0.621469          0.339861
# 1       Lasso Regression  No outliers           0.621427          0.615350
# 2       Ridge Regression  No outliers           0.621136          0.616527
# 3  KNeighbors Regression  No outliers           0.616137          0.408698
# 4                    SVM  No outliers          -0.047866         -0.051842
#
#   r2_score Mean_squared_error  Mean_absolute_error
# 0    0.340    46262383262.147           116607.458
# 1    0.615    26956193878.704           114152.710
# 2    0.617    26873649651.105           114151.177
# 3    0.409    41438250394.440           138810.442
# 4   -0.052    73712825494.029           181400.770

# %% [markdown]
# ### 6. Decision Tree

# %%
dt_model = DecisionTreeRegressor()
model_performance(dt_model, 'Decision Tree', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Decision Tree
# --------------------
# Accuracy score for training data:  0.9998257944485558
# Accuracy score for test data:  0.37772717305232495
#                   METHOD    Data type  Training_accuracy  Testing_accuracy  \
# 0      Linear Regression  No outliers           0.621469          0.339861
# 1       Lasso Regression  No outliers           0.621427          0.615350
# 2       Ridge Regression  No outliers           0.621136          0.616527
# 3  KNeighbors Regression  No outliers           0.616137          0.408698
# 4                    SVM  No outliers          -0.047866         -0.051842
# 5          Decision Tree  No outliers           0.999826          0.377727
#
#   r2_score Mean_squared_error  Mean_absolute_error
# 0    0.340    46262383262.147           116607.458
# 1    0.615    26956193878.704           114152.710
# 2    0.617    26873649651.105           114151.177
# 3    0.409    41438250394.440           138810.442
# ...

# %% [markdown]
# ### 7. RandomForest

# %%
rf_model = RandomForestRegressor()
model_performance(rf_model, 'Random Forest', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Random Forest
# --------------------
# Accuracy score for training data:  0.9554357771219395
# Accuracy score for test data:  0.6630937621402454
#                   METHOD    Data type  Training_accuracy  Testing_accuracy  \
# 0      Linear Regression  No outliers           0.621469          0.339861
# 1       Lasso Regression  No outliers           0.621427          0.615350
# 2       Ridge Regression  No outliers           0.621136          0.616527
# 3  KNeighbors Regression  No outliers           0.616137          0.408698
# 4                    SVM  No outliers          -0.047866         -0.051842
# 5          Decision Tree  No outliers           0.999826          0.377727
# 6          Random Forest  No outliers           0.955436          0.663094
#
#   r2_score Mean_squared_error  Mean_absolute_error
# 0    0.340    46262383262.147           116607.458
# 1    0.615    26956193878.704           114152.710
# 2    0.617    26873649651.105           114151.177
# ...

# %% [markdown]
# ### PART - 2: Standardization and Parameter tuning of above models for improvisation of model performance.

# %% [markdown]
# #### Standardization of the data (Log Transformation)

# %%
transformed_data = data.copy(deep=True)

# %%
transformed_data = transformed_data.drop(['cid','month_year','yr_renovated','zipcode','lat','long'],axis=1)

# %%
transformed_data['ceil_measure_log'] = np.log10(transformed_data.ceil_measure)
transformed_data.drop(['ceil_measure'],axis=1,inplace=True)
transformed_data.head(2)
# Out:
#     price  room_bed  room_bath  living_measure  lot_measure  ceil  coast  \
# 0  808100         4       3.25            3020        13457   1.0      0
# 1  277500         4       2.50            2550         7500   1.0      0
#
#    sight  condition  quality  basement  yr_built  living_measure15  \
# 0      0          5        9         0      1956              2120
# 1      0          3        8       800      1976              2260
#
#    lot_measure15  furnished  total_area  sold_year  house_age  \
# 0           7553          1       16477       2014         58
# 1           8800          0       10050       2014         38
#
#    ceil_measure_log
# 0          3.480007
# 1          3.243038

# %%
transformed_data['living_measure_log'] = np.log10(transformed_data.living_measure)
transformed_data.drop(['living_measure'],axis=1,inplace=True)
transformed_data.head(2)
# Out:
#     price  room_bed  room_bath  lot_measure  ceil  coast  sight  condition  \
# 0  808100         4       3.25        13457   1.0      0      0          5
# 1  277500         4       2.50         7500   1.0      0      0          3
#
#    quality  basement  yr_built  living_measure15  lot_measure15  furnished  \
# 0        9         0      1956              2120           7553          1
# 1        8       800      1976              2260           8800          0
#
#    total_area  sold_year  house_age  ceil_measure_log  living_measure_log
# 0       16477       2014         58          3.480007            3.480007
# 1       10050       2014         38          3.243038            3.406540

# %%
transformed_data['lot_measure_log'] = np.log10(transformed_data.lot_measure)
transformed_data.drop(['lot_measure'],axis=1,inplace=True)
transformed_data.head(2)
# Out:
#     price  room_bed  room_bath  ceil  coast  sight  condition  quality  \
# 0  808100         4       3.25   1.0      0      0          5        9
# 1  277500         4       2.50   1.0      0      0          3        8
#
#    basement  yr_built  living_measure15  lot_measure15  furnished  total_area  \
# 0         0      1956              2120           7553          1       16477
# 1       800      1976              2260           8800          0       10050
#
#    sold_year  house_age  ceil_measure_log  living_measure_log  lot_measure_log
# 0       2014         58          3.480007            3.480007         4.128948
# 1       2014         38          3.243038            3.406540         3.875061

# %%
edited_data.columns
# Out:
# Index(['price', 'living_measure', 'lot_measure', 'ceil_measure', 'basement',
#        'yr_built', 'living_measure15', 'lot_measure15', 'total_area',
#        'sold_year', 'house_age', 'room_bed_1', 'room_bed_2', 'room_bed_3',
#        'room_bed_4', 'room_bed_5', 'room_bed_6', 'room_bed_7', 'room_bed_8',
#        'room_bed_9', 'room_bed_10', 'room_bed_11', 'room_bath_0.5',
#        'room_bath_0.75', 'room_bath_1.0', 'room_bath_1.25', 'room_bath_1.5',
#        'room_bath_1.75', 'room_bath_2.0', 'room_bath_2.25', 'room_bath_2.5',
#        'room_bath_2.75', 'room_bath_3.0', 'room_bath_3.25', 'room_bath_3.5',
#        'room_bath_3.75', 'room_bath_4.0', 'room_bath_4.25', 'room_bath_4.5',
#        'room_bath_4.75', 'room_bath_5.0', 'room_bath_5.25', 'room_bath_5.75',
#        'ceil_1.5', 'ceil_2.0', 'ceil_2.5', 'ceil_3.0', 'ceil_3.5', 'coast_1',
#        'sight_1', 'sight_2', 'sight_3', 'sight_4', 'condition_2',
# ...

# %%
transformed_data.columns
# Out:
# Index(['price', 'room_bed', 'room_bath', 'ceil', 'coast', 'sight', 'condition',
#        'quality', 'basement', 'yr_built', 'living_measure15', 'lot_measure15',
#        'furnished', 'total_area', 'sold_year', 'house_age', 'ceil_measure_log',
#        'living_measure_log', 'lot_measure_log'],
#       dtype='object')

# %%
transformed_data.shape
# Out:
# (18287, 19)

# %%
transformed_data = pd.get_dummies(transformed_data, columns=['room_bed', 'room_bath', 'ceil', 'coast', 'sight', 'condition', 'quality', 'furnished'],drop_first=True)

# %%
transformed_data.columns
# Out:
# Index(['price', 'basement', 'yr_built', 'living_measure15', 'lot_measure15',
#        'total_area', 'sold_year', 'house_age', 'ceil_measure_log',
#        'living_measure_log', 'lot_measure_log', 'room_bed_1', 'room_bed_2',
#        'room_bed_3', 'room_bed_4', 'room_bed_5', 'room_bed_6', 'room_bed_7',
#        'room_bed_8', 'room_bed_9', 'room_bed_10', 'room_bed_11',
#        'room_bath_0.5', 'room_bath_0.75', 'room_bath_1.0', 'room_bath_1.25',
#        'room_bath_1.5', 'room_bath_1.75', 'room_bath_2.0', 'room_bath_2.25',
#        'room_bath_2.5', 'room_bath_2.75', 'room_bath_3.0', 'room_bath_3.25',
#        'room_bath_3.5', 'room_bath_3.75', 'room_bath_4.0', 'room_bath_4.25',
#        'room_bath_4.5', 'room_bath_4.75', 'room_bath_5.0', 'room_bath_5.25',
#        'room_bath_5.75', 'ceil_1.5', 'ceil_2.0', 'ceil_2.5', 'ceil_3.0',
#        'ceil_3.5', 'coast_1', 'sight_1', 'sight_2', 'sight_3', 'sight_4',
#        'condition_2', 'condition_3', 'condition_4', 'condition_5', 'quality_4',
# ...

# %%
# Separate the target variable and dependent variables and split the data into train and test data
Xt = transformed_data.drop(columns = 'price', axis =1)
Yt = transformed_data['price']

# %%
Xt_train, Xt_test, Yt_train, Yt_test = train_test_split(Xt,Yt, test_size = 0.3, random_state = 42)

# %% [markdown]
# #### 1. Linear Regression

# %%
model_performance(LR_model, 'Linear Regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Linear Regression
# --------------------
# Accuracy score for training data:  0.6235703647959003
# Accuracy score for test data:  0.618483349487357
#                   METHOD        Data type  Training_accuracy  \
# 0      Linear Regression      No outliers           0.621469
# 1       Lasso Regression      No outliers           0.621427
# 2       Ridge Regression      No outliers           0.621136
# 3  KNeighbors Regression      No outliers           0.616137
# 4                    SVM      No outliers          -0.047866
# 5          Decision Tree      No outliers           0.999826
# 6          Random Forest      No outliers           0.955436
# 7      Linear Regression  log transformed           0.623570
#
#    Testing_accuracy r2_score Mean_squared_error  Mean_absolute_error
# 0          0.339861    0.340    46262383262.147           116607.458
# 1          0.615350    0.615    26956193878.704           114152.710
# ...

# %% [markdown]
# #### 2. Lasso Regression

# %%
model_performance(lasso_reg_model, 'Lasso Regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Lasso Regression
# --------------------
# Accuracy score for training data:  0.6235121930796947
# Accuracy score for test data:  0.6169963115648597
#                   METHOD        Data type  Training_accuracy  \
# 0      Linear Regression      No outliers           0.621469
# 1       Lasso Regression      No outliers           0.621427
# 2       Ridge Regression      No outliers           0.621136
# 3  KNeighbors Regression      No outliers           0.616137
# 4                    SVM      No outliers          -0.047866
# 5          Decision Tree      No outliers           0.999826
# 6          Random Forest      No outliers           0.955436
# 7      Linear Regression  log transformed           0.623570
# 8       Lasso Regression  log transformed           0.623512
#
#    Testing_accuracy r2_score Mean_squared_error  Mean_absolute_error
# 0          0.339861    0.340    46262383262.147           116607.458
# ...

# %% [markdown]
# #### 3. Ridge Regression

# %%
model_performance(RR_model, 'Ridge Regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Ridge Regression
# --------------------
# Accuracy score for training data:  0.6231461783016048
# Accuracy score for test data:  0.6181094970834022
#                   METHOD        Data type  Training_accuracy  \
# 0      Linear Regression      No outliers           0.621469
# 1       Lasso Regression      No outliers           0.621427
# 2       Ridge Regression      No outliers           0.621136
# 3  KNeighbors Regression      No outliers           0.616137
# 4                    SVM      No outliers          -0.047866
# 5          Decision Tree      No outliers           0.999826
# 6          Random Forest      No outliers           0.955436
# 7      Linear Regression  log transformed           0.623570
# 8       Lasso Regression  log transformed           0.623512
# 9       Ridge Regression  log transformed           0.623146
#
#    Testing_accuracy r2_score Mean_squared_error  Mean_absolute_error
# 0          0.339861    0.340    46262383262.147           116607.458
# ...

# %% [markdown]
# #### 4. KNN Regression

# %%
model_performance(KNN_model, 'KNeighbors Regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  KNeighbors Regression
# --------------------
# Accuracy score for training data:  0.5604251717309887
# Accuracy score for test data:  0.33275494449461296
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
#
# ...

# %% [markdown]
# #### 5. SVM

# %%
model_performance(svm_model, 'SVM', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  SVM
# --------------------
# Accuracy score for training data:  -0.0480702244235065
# Accuracy score for test data:  -0.05201942953098948
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
#
# ...

# %% [markdown]
# #### 6. Decision Tree

# %%
model_performance(dt_model, 'Decision Tree', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Decision Tree
# --------------------
# Accuracy score for training data:  0.9998257944485558
# Accuracy score for test data:  0.38313819674796457
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### 7. Random Forest

# %%
model_performance(rf_model, 'Random Forest', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Random Forest
# --------------------
# Accuracy score for training data:  0.9548495992400592
# Accuracy score for test data:  0.6570622841571112
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### INSIGHTS:
# + Before standardization Lasso regression and ridge regression performed better, where as the other models were over-fitting
# + After standardization the performance of linear regression has been improved. Where as other models did not perform any better.
# + For further improvisation of model performance let us use hyperparameter tuning and cross validation

# %% [markdown]
# #### Hyperparameter tuning and cross validtion

# %% [markdown]
# #### 1. Linear Regression

# %%
# Grid search cross validation
lr_param_dict = {"n_jobs": [1,-1]}

clf = GridSearchCV(LR_model, lr_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# {'n_jobs': 1}

# %% [markdown]
# ##### 1.1  Linear regression with no outliers

# %%
LR_final_model = LinearRegression(n_jobs=1)
model_performance(LR_final_model, 'Linear regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Linear regression
# --------------------
# Accuracy score for training data:  0.6214685897065774
# Accuracy score for test data:  0.33986070414112834
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# ##### 1.2 Linear regression for log transfromed data

# %%
model_performance(LR_final_model, 'Linear regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Linear regression
# --------------------
# Accuracy score for training data:  0.6235703647959003
# Accuracy score for test data:  0.618483349487357
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### 2. Lasso Regression

# %%
lasso_param_dict = {"alpha": [1,5,10,50,100],
                   "selection" : ['cyclic', 'random']}
clf = GridSearchCV(lasso_reg_model, lasso_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'alpha': 10, 'selection': 'cyclic'}

# %% [markdown]
# ##### 2.1 Lasso Regression with no outliers

# %%
lasso_final_model = Lasso(alpha = 10, selection = 'cyclic')
model_performance(lasso_final_model, 'Lasso Regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Lasso Regression
# --------------------
# Accuracy score for training data:  0.6212728683706606
# Accuracy score for test data:  0.6164259980623966
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# ##### 2.2 Lasso Regression for log transformed data

# %%
model_performance(lasso_final_model, 'Lasso Regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Lasso Regression
# --------------------
# Accuracy score for training data:  0.6233548424716806
# Accuracy score for test data:  0.6179534967007407
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### 3. Ridge Regression

# %%
ridge_param_dict = {"alpha": [1,5,10,50,100]
                   }
clf = GridSearchCV(RR_model, ridge_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# {'alpha': 5}

# %% [markdown]
# ##### 3.1 Ridge regression with no outliers

# %%
ridge_final_model = Ridge(alpha = 5)
model_performance(ridge_final_model, 'Ridge regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Ridge regression
# --------------------
# Accuracy score for training data:  0.6204623137175365
# Accuracy score for test data:  0.6146562637813557
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# ##### 3.2 Ridge regression for log transformed data

# %%
model_performance(ridge_final_model, 'Ridge regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Ridge regression
# --------------------
# Accuracy score for training data:  0.6219551697842276
# Accuracy score for test data:  0.6156000263469399
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### 4. KNN Regressor

# %%
# Grid search cross validation
knn_param_dict = {"weights": ['uniform','distance'],
              "metric": ['euclidean', 'manhattan'],
              "n_neighbors": [1,3,5,15],}

clf = GridSearchCV(KNN_model, knn_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}

# %% [markdown]
# ##### 4.1 KNN regression without outliers

# %%
KNN_final_model = KNeighborsRegressor(metric='manhattan', n_neighbors=15, weights='distance')
model_performance(KNN_final_model, 'KNeighbors Regression', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  KNeighbors Regression
# --------------------
# Accuracy score for training data:  0.9998257944485558
# Accuracy score for test data:  0.46693140539501665
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# ##### 4.2 KNN regression for log transformed data

# %%
model_performance(KNN_final_model, 'KNeighbors Regression', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  KNeighbors Regression
# --------------------
# Accuracy score for training data:  0.9998257944485558
# Accuracy score for test data:  0.4035818286506374
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### 5. SVM Regressor

# %%
# Grid search cross validation

svr_param_dict = {"C": [0.1, 1, 10],
              "gamma": [0.001, 0.01, 0.1],}

clf = GridSearchCV(svm_model, svr_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# {'C': 10, 'gamma': 0.001}

# %% [markdown]
# ##### 5.1 SVM Regressor with no outliers

# %%
svm_final_model = SVR(C=10, gamma = 0.001)
model_performance(svm_final_model, 'SVM', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  SVM
# --------------------
# Accuracy score for training data:  -0.04815102322856002
# Accuracy score for test data:  -0.05214297619077213
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# ##### 5.2 SVM Regressor for log transformed data

# %%
model_performance(svm_final_model, 'SVM', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  SVM
# --------------------
# Accuracy score for training data:  -0.04815064917326528
# Accuracy score for test data:  -0.05214252043658352
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### 6. Decision Tree

# %%
# Grid search cross validation
dtr_param_dict = {"max_depth": [3, 5,7],
              "max_features": [2,4,6],
              "min_samples_leaf": [3,5],
              "criterion": ["mse", "mae"]}

clf = GridSearchCV(dt_model, dtr_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# {'criterion': 'mae', 'max_depth': 7, 'max_features': 6, 'min_samples_leaf': 5}

# %% [markdown]
# ##### 6.1 Decision Tree with no outliers

# %%
dt_final_model = DecisionTreeRegressor(criterion = 'mae', max_depth = 7, max_features=6, min_samples_leaf=5) 
model_performance(dt_final_model, 'Decision Tree', 'No outliers', X_train, X_test, Y_train, Y_test)
# Out:
# Method:  Decision Tree
# --------------------
# Accuracy score for training data:  0.549383994707491
# Accuracy score for test data:  0.47681836758412566
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# ##### 6.2 Decision Tree for log transformed data

# %%
model_performance(dt_final_model, 'Decision Tree', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
# Out:
# Method:  Decision Tree
# --------------------
# Accuracy score for training data:  0.4571319763049545
# Accuracy score for test data:  0.4027527738488397
#                    METHOD        Data type  Training_accuracy  \
# 0       Linear Regression      No outliers           0.621469
# 1        Lasso Regression      No outliers           0.621427
# 2        Ridge Regression      No outliers           0.621136
# 3   KNeighbors Regression      No outliers           0.616137
# 4                     SVM      No outliers          -0.047866
# 5           Decision Tree      No outliers           0.999826
# 6           Random Forest      No outliers           0.955436
# 7       Linear Regression  log transformed           0.623570
# 8        Lasso Regression  log transformed           0.623512
# 9        Ridge Regression  log transformed           0.623146
# 10  KNeighbors Regression  log transformed           0.560425
# 11                    SVM  log transformed          -0.048070
# ...

# %% [markdown]
# #### 7 Random Forest

# %%
# Grid search cross validation
rf_param_dict = {"max_features": [2,4],
              "min_samples_leaf": [3,5],
              "n_estimators":[100,300],
              "criterion": ["mse", "mae"]}

clf = GridSearchCV(rf_model, rf_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits

# %% [markdown]
# ##### 7.1 Random forest with no outliers

# %%
rf_final_model = RandomForestRegressor(n_estimators=100, criterion='mse', max_features=6, min_samples_leaf=3)
model_performance(rf_final_model, 'Random Forest', 'No outliers', X_train, X_test, Y_train, Y_test)

# %% [markdown]
# ##### 7.2 Random forest for log transformed data

# %%
model_performance(rf_final_model, 'Random Forest', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)

# %% [markdown]
# #### 8. Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr_model = GradientBoostingRegressor()

# %%
# Grid search cross validation
gbr_param_dict = {"max_depth": [3, 5],
              "max_features": [2,4],
              "n_estimators":[100,200]}
              

clf = GridSearchCV(gbr_model, gbr_param_dict, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X_train, Y_train)

clf.best_params_

# %% [markdown]
# ##### 8.1 Gradient boost with no outliers

# %%
gbr_final_model = GradientBoostingRegressor(n_estimators = 200, learning_rate = 0.1)
model_performance(gbr_final_model, 'Gradient Boost', 'No outliers', X_train, X_test, Y_train, Y_test)

# %% [markdown]
# ##### 8.2 Gradient boost for log transformed data

# %%
model_performance(gbr_final_model, 'Gradient Boost', 'log transformed', Xt_train, Xt_test, Yt_train, Yt_test)
